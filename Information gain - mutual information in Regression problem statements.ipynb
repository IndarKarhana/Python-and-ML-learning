# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("train.csv")
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
numeric_lst = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numeric_cols = list(df.select_dtypes(include = numeric_lst).columns)

# %%
df1 = df[numeric_cols]

# %%
df1.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  OpenPorchSF  \
# 0          2003       196.0         706  ...           0           61
# 1          1976         0.0         978  ...         298            0
# 2          2002       162.0         486  ...           0           42
# 3          1970         0.0         216  ...           0           35
# 4          2000       350.0         655  ...         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %%
df1.drop("Id", axis = 1)
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60         65.0     8450            7            5       2003
# 1             20         80.0     9600            6            8       1976
# 2             60         68.0    11250            7            5       2001
# 3             70         60.0     9550            7            5       1915
# 4             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1455          60         62.0     7917            6            5       1999
# 1456          20         85.0    13175            6            6       1978
# 1457          70         66.0     9042            7            9       1941
# 1458          20         68.0     9717            5            6       1950
# 1459          20         75.0     9937            5            6       1965
#
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df1.drop(labels = ['SalePrice'], axis = 1),
                                                   df1['SalePrice'],
                                                   test_size = 0.3,
                                                   random_state = 0)

# %%
X_train
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 64      65          60          NaN     9375            7            5
# 682    683         120          NaN     2887            6            5
# 960    961          20         50.0     7207            5            7
# 1384  1385          50         60.0     9060            6            5
# 1100  1101          30         60.0     8400            2            5
# ...    ...         ...          ...      ...          ...          ...
# 763    764          60         82.0     9430            8            5
# 835    836          20         60.0     9600            4            7
# 1216  1217          90         68.0     8930            6            5
# 559    560         120          NaN     3196            7            5
# 684    685          60         58.0    16770            7            5
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  GarageArea  \
# ...

# %%
X_train.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# LotFrontage      189
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         5
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       54
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# dtype: int64

# %%
from sklearn.feature_selection import mutual_info_regression
mutual_info = mutual_info_regression(X_train.fillna(0), y_train) #determine the mutual information
mutual_info
# Out:
# array([0.        , 0.25329894, 0.20834334, 0.16571101, 0.52610899,
#        0.11180316, 0.34638349, 0.24947076, 0.09747788, 0.16226168,
#        0.00471714, 0.11227259, 0.38266714, 0.31093183, 0.22306936,
#        0.00524611, 0.47916974, 0.02716651, 0.        , 0.25516788,
#        0.08080886, 0.04893676, 0.03298453, 0.1722259 , 0.19249157,
#        0.27031981, 0.37276984, 0.37138886, 0.06339372, 0.16975497,
#        0.01329993, 0.        , 0.02372428, 0.00286513, 0.        ,
#        0.        , 0.01230283])

# %%
mutual_info = pd.Series(mutual_info)
mutual_info.index = X_train.columns
mutual_info.sort_values(ascending=False)
# Out:
# OverallQual      0.526109
# GrLivArea        0.479170
# TotalBsmtSF      0.382667
# GarageCars       0.372770
# GarageArea       0.371389
# YearBuilt        0.346383
# 1stFlrSF         0.310932
# GarageYrBlt      0.270320
# FullBath         0.255168
# MSSubClass       0.253299
# YearRemodAdd     0.249471
# 2ndFlrSF         0.223069
# LotFrontage      0.208343
# Fireplaces       0.192492
# TotRmsAbvGrd     0.172226
# OpenPorchSF      0.169755
# LotArea          0.165711
# BsmtFinSF1       0.162262
# BsmtUnfSF        0.112273
# OverallCond      0.111803
# MasVnrArea       0.097478
# HalfBath         0.080809
# WoodDeckSF       0.063394
# BedroomAbvGr     0.048937
# KitchenAbvGr     0.032985
# BsmtFullBath     0.027167
# ScreenPorch      0.023724
# EnclosedPorch    0.013300
# YrSold           0.012303
# LowQualFinSF     0.005246
# BsmtFinSF2       0.004717
# PoolArea         0.002865
# MiscVal          0.000000
# MoSold           0.000000
# Id               0.000000
# ...

# %%
#here what we can do is take top 10 features
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mutual_info.sort_values(ascending=False).plot.bar(figsize=(15,5))
# Out:
# <AxesSubplot:>

# %%
from sklearn.feature_selection import SelectPercentile

# %%
# selecting the top 20 percentile
selected_top_columns = SelectPercentile(mutual_info_regression, percentile = 20)
selected_top_columns.fit(X_train.fillna(0), y_train)
X_train.columns[selected_top_columns.get_support()]  ## get_support() give us the indexces
# Out:
# Index(['OverallQual', 'YearBuilt', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea',
#        'GarageYrBlt', 'GarageCars', 'GarageArea'],
#       dtype='object')
